# %% [markdown]
# <a href="https://colab.research.google.com/github/soroush-04/Intoxication-Behavior-Visualization/blob/main/Intoxication.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from bisect import bisect_right
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/all_accelerometer_data_pids_13.csv')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                    time     pid         x         y         z
# 0                     0  JB3156  0.000000  0.000000  0.000000
# 1                     0  CC6740  0.000000  0.000000  0.000000
# 2         1493733882409  SA0297  0.075800  0.027300 -0.010200
# 3         1493733882455  SA0297 -0.035900  0.079400  0.003700
# 4         1493733882500  SA0297 -0.242700 -0.086100 -0.016300
# ...                 ...     ...       ...       ...       ...
# 14057562  1493829248196  CC6740 -0.133956  0.124726 -0.010736
# 14057563  1493829248220  CC6740 -0.100764  0.180872  0.046449
# 14057564  1493829248245  CC6740 -0.131853  0.195934  0.181088
# 14057565  1493829248270  CC6740 -0.149704  0.194482  0.202393
# 14057566  1493829248294  CC6740 -0.107288  0.153548  0.168595
#
# [14057567 rows x 5 columns]>

# %%
pids = pd.unique(df['pid'])
pids
acc={}

for pid in pids:
  acc[pid] = df.loc[df['pid']==pid]
  acc[pid] = acc[pid][acc[pid]['time']!=0]
  acc[pid]['time'] //= 1000
  acc[pid]['datetime'] = pd.to_datetime(acc[pid]['time'], unit='s')
  acc[pid].sort_values(by=['time'])

# %%
# merged={}
# for pid in pids:
#   merged[pid] = pd.concat([tac[pid],pd.DataFrame(columns=list('xyz'))])
#   for idx in range(len(merged[pid])):
#     t = tac[pid].timestamp.values[idx]
#     row = bisect_right(acc[pid].time.values, t)
#     print(merged[pid]['x'].iloc[idx])
#     print(acc[pid]['x'].iloc[row])
#     merged[pid]['x'].iloc[idx] = acc[pid]['x'].iloc[row]
#     merged[pid]['y'].iloc[idx] = acc[pid]['y'].iloc[row]
#     merged[pid]['z'].iloc[idx] = acc[pid]['z'].iloc[row]

# %% [markdown]
# # Plot x,y,z

# %%
acc[pids[0]]
# Out:
#                time     pid         x         y          z            datetime
# 541149   1493739732  JB3156 -2.556815  8.312009  14.090558 2017-05-02 15:42:12
# 541154   1493739732  JB3156 -2.499538  8.636412  13.906186 2017-05-02 15:42:12
# 541159   1493739732  JB3156 -2.471458  8.687223  13.677473 2017-05-02 15:42:12
# 541163   1493739732  JB3156 -2.244561  8.832140  13.288850 2017-05-02 15:42:12
# 541169   1493739732  JB3156 -2.453742  9.053032  12.610379 2017-05-02 15:42:12
# ...             ...     ...       ...       ...        ...                 ...
# 7792214  1493784075  JB3156 -0.224899 -0.009760  -0.068496 2017-05-03 04:01:15
# 7792219  1493784075  JB3156 -0.148706 -0.015424   0.107965 2017-05-03 04:01:15
# 7792224  1493784075  JB3156 -0.077544 -0.057442  -0.079593 2017-05-03 04:01:15
# 7792227  1493784075  JB3156 -0.036513 -0.059515  -0.106539 2017-05-03 04:01:15
# 7792231  1493784075  JB3156 -0.301496 -0.128987  -0.262350 2017-05-03 04:01:15
#
# ...

# %%
plt.figure(figsize=(16,8))
plt.subplot(3, 1, 1)
plt.title("Accelerometer Data for JB3156")
plt.plot(acc[pids[0]]['datetime'], acc[pids[0]]['x'], '.-', color='yellowgreen')
plt.ylabel('X acceleration')


plt.subplot(3, 1, 2)
plt.plot(acc[pids[0]]['datetime'], acc[pids[0]]['y'], '.-', color='salmon')
plt.ylabel('Y acceleration')


plt.subplot(3, 1, 3)
plt.plot(acc[pids[0]]['datetime'], acc[pids[0]]['z'], '.-', color='indigo')
plt.ylabel('Z acceleration')
plt.xlabel('Datetime')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(3, 1, 1)
plt.title("Accelerometer Data for CC6740")
plt.plot(acc[pids[1]]['datetime'], acc[pids[1]]['x'], '.-', color='yellowgreen')
plt.ylabel('X acceleration')


plt.subplot(3, 1, 2)
plt.plot(acc[pids[1]]['datetime'], acc[pids[1]]['y'], '.-', color='salmon')
plt.ylabel('Y acceleration')


plt.subplot(3, 1, 3)
plt.plot(acc[pids[1]]['datetime'], acc[pids[1]]['z'], '.-', color='indigo')
plt.ylabel('Z acceleration')
plt.xlabel('Datetime')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(3, 1, 1)
plt.title("Accelerometer Data for SA0297")
plt.plot(acc[pids[2]]['datetime'], acc[pids[2]]['x'], '.-', color='yellowgreen')
plt.ylabel('X acceleration')


plt.subplot(3, 1, 2)
plt.plot(acc[pids[2]]['datetime'], acc[pids[2]]['y'], '.-', color='salmon')
plt.ylabel('Y acceleration')


plt.subplot(3, 1, 3)
plt.plot(acc[pids[2]]['datetime'], acc[pids[2]]['z'], '.-', color='indigo')
plt.ylabel('Z acceleration')
plt.xlabel('Datetime')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(3, 1, 1)
plt.title("Accelerometer Data for PC6771")
plt.plot(acc[pids[3]]['datetime'], acc[pids[3]]['x'], '.-', color='yellowgreen')
plt.ylabel('X acceleration')


plt.subplot(3, 1, 2)
plt.plot(acc[pids[3]]['datetime'], acc[pids[3]]['y'], '.-', color='salmon')
plt.ylabel('Y acceleration')


plt.subplot(3, 1, 3)
plt.plot(acc[pids[3]]['datetime'], acc[pids[3]]['z'], '.-', color='indigo')
plt.ylabel('Z acceleration')
plt.xlabel('Datetime')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(3, 1, 1)
plt.title("Accelerometer Data for BK7610")
plt.plot(acc[pids[4]]['datetime'], acc[pids[4]]['x'], '.-', color='yellowgreen')
plt.ylabel('X acceleration')


plt.subplot(3, 1, 2)
plt.plot(acc[pids[4]]['datetime'], acc[pids[4]]['y'], '.-', color='salmon')
plt.ylabel('Y acceleration')


plt.subplot(3, 1, 3)
plt.plot(acc[pids[4]]['datetime'], acc[pids[4]]['z'], '.-', color='indigo')
plt.ylabel('Z acceleration')
plt.xlabel('Datetime')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(3, 1, 1)
plt.title("Accelerometer Data for DC6359")
plt.plot(acc[pids[5]]['datetime'], acc[pids[5]]['x'], '.-', color='yellowgreen')
plt.ylabel('X acceleration')


plt.subplot(3, 1, 2)
plt.plot(acc[pids[5]]['datetime'], acc[pids[5]]['y'], '.-', color='salmon')
plt.ylabel('Y acceleration')


plt.subplot(3, 1, 3)
plt.plot(acc[pids[5]]['datetime'], acc[pids[5]]['z'], '.-', color='indigo')
plt.ylabel('Z acceleration')
plt.xlabel('Datetime')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(3, 1, 1)
plt.title("Accelerometer Data for MC7070")
plt.plot(acc[pids[6]]['datetime'], acc[pids[6]]['x'], '.-', color='yellowgreen')
plt.ylabel('X acceleration')


plt.subplot(3, 1, 2)
plt.plot(acc[pids[6]]['datetime'], acc[pids[6]]['y'], '.-', color='salmon')
plt.ylabel('Y acceleration')


plt.subplot(3, 1, 3)
plt.plot(acc[pids[6]]['datetime'], acc[pids[6]]['z'], '.-', color='indigo')
plt.ylabel('Z acceleration')
plt.xlabel('Datetime')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(3, 1, 1)
plt.title("Accelerometer Data for MJ8002")
plt.plot(acc[pids[7]]['datetime'], acc[pids[7]]['x'], '.-', color='yellowgreen')
plt.ylabel('X acceleration')


plt.subplot(3, 1, 2)
plt.plot(acc[pids[7]]['datetime'], acc[pids[7]]['y'], '.-', color='salmon')
plt.ylabel('Y acceleration')


plt.subplot(3, 1, 3)
plt.plot(acc[pids[7]]['datetime'], acc[pids[7]]['z'], '.-', color='indigo')
plt.ylabel('Z acceleration')
plt.xlabel('Datetime')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(3, 1, 1)
plt.title("Accelerometer Data for BU4707")
plt.plot(acc[pids[8]]['datetime'], acc[pids[8]]['x'], '.-', color='yellowgreen')
plt.ylabel('X acceleration')


plt.subplot(3, 1, 2)
plt.plot(acc[pids[8]]['datetime'], acc[pids[8]]['y'], '.-', color='salmon')
plt.ylabel('Y acceleration')


plt.subplot(3, 1, 3)
plt.plot(acc[pids[8]]['datetime'], acc[pids[8]]['z'], '.-', color='indigo')
plt.ylabel('Z acceleration')
plt.xlabel('Datetime')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(3, 1, 1)
plt.title("Accelerometer Data for JR8022")
plt.plot(acc[pids[9]]['datetime'], acc[pids[9]]['x'], '.-', color='yellowgreen')
plt.ylabel('X acceleration')


plt.subplot(3, 1, 2)
plt.plot(acc[pids[9]]['datetime'], acc[pids[9]]['y'], '.-', color='salmon')
plt.ylabel('Y acceleration')


plt.subplot(3, 1, 3)
plt.plot(acc[pids[9]]['datetime'], acc[pids[9]]['z'], '.-', color='indigo')
plt.ylabel('Z acceleration')
plt.xlabel('Datetime')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(3, 1, 1)
plt.title("Accelerometer Data for HV0618")
plt.plot(acc[pids[10]]['datetime'], acc[pids[10]]['x'], '.-', color='yellowgreen')
plt.ylabel('X acceleration')


plt.subplot(3, 1, 2)
plt.plot(acc[pids[10]]['datetime'], acc[pids[10]]['y'], '.-', color='salmon')
plt.ylabel('Y acceleration')


plt.subplot(3, 1, 3)
plt.plot(acc[pids[10]]['datetime'], acc[pids[10]]['z'], '.-', color='indigo')
plt.ylabel('Z acceleration')
plt.xlabel('Datetime')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(3, 1, 1)
plt.title("Accelerometer Data for SF3079")
plt.plot(acc[pids[11]]['datetime'], acc[pids[11]]['x'], '.-', color='yellowgreen')
plt.ylabel('X acceleration')


plt.subplot(3, 1, 2)
plt.plot(acc[pids[11]]['datetime'], acc[pids[11]]['y'], '.-', color='salmon')
plt.ylabel('Y acceleration')


plt.subplot(3, 1, 3)
plt.plot(acc[pids[11]]['datetime'], acc[pids[11]]['z'], '.-', color='indigo')
plt.ylabel('Z acceleration')
plt.xlabel('Datetime')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(3, 1, 1)
plt.title("Accelerometer Data for DK3500")
plt.plot(acc[pids[12]]['datetime'], acc[pids[12]]['x'], '.-', color='yellowgreen')
plt.ylabel('X acceleration')


plt.subplot(3, 1, 2)
plt.plot(acc[pids[12]]['datetime'], acc[pids[12]]['y'], '.-', color='salmon')
plt.ylabel('Y acceleration')


plt.subplot(3, 1, 3)
plt.plot(acc[pids[12]]['datetime'], acc[pids[12]]['z'], '.-', color='indigo')
plt.ylabel('Z acceleration')
plt.xlabel('Datetime')
plt.show()

# %% [markdown]
# # End of x, y, z plots

# %%
merged={}
tac={}
for pid in pids:
  tac_path = '/content/drive/MyDrive/Datasets/clean_tac/'+ pid +'_clean_TAC.csv'
  tac[pid] = pd.read_csv(tac_path)
  tac[pid].sort_values(by=['timestamp'])
  merged[pid] = pd.merge(acc[pid], tac[pid], how='inner', left_on='time', right_on='timestamp')
  tac[pid]['datetime'] = pd.to_datetime(tac[pid]['timestamp'], unit='s')

# %%
 plt.figure(figsize=(20,5))
    # Create datetime for reference in plot.

for pid in pids:
    plt.plot(tac[pid]["datetime"], tac[pid]["TAC_Reading"], marker="o", linestyle="", label=pid)
plt.axhline(y=0.08, color='r', linestyle='-')
plt.title("TAC Readings Over Time By Subject")
plt.xlabel("Datetime")
plt.legend()
plt.show()

# %%
print(len(acc[pids[0]]), len(tac[pids[0]]), len(merged[pids[0]]))

len(tac[pids[10]])
print(pd.merge(acc[pids[0]], tac[pids[0]], how='inner', left_on='time', right_on='timestamp'))
print(len(pd.unique(acc[pids[0]]['time'])))
# Out:
# 1177748 55 720
#            time     pid         x          y          z          datetime_x  \
# 0    1493740607  JB3156  1.829285  10.341198  10.899044 2017-05-02 15:56:47
# 1    1493740607  JB3156  1.981330   9.302634  10.169534 2017-05-02 15:56:47
# 2    1493740607  JB3156  1.193751   6.882037   8.002905 2017-05-02 15:56:47
# 3    1493740607  JB3156  1.087926   3.531353  10.245369 2017-05-02 15:56:47
# 4    1493740607  JB3156 -0.092390   3.977956  13.346973 2017-05-02 15:56:47
# ..          ...     ...       ...        ...        ...                 ...
# 715  1493782978  JB3156  0.054742  -0.075326  -0.261302 2017-05-03 03:42:58
# 716  1493782978  JB3156  0.064429  -0.069424  -0.282848 2017-05-03 03:42:58
# 717  1493782978  JB3156  0.038093  -0.053862  -0.239753 2017-05-03 03:42:58
# 718  1493782978  JB3156  0.046472  -0.065833  -0.266089 2017-05-03 03:42:58
# 719  1493782978  JB3156 -0.008594  -0.037103  -0.237358 2017-05-03 03:42:58
#
# ...

# %% [markdown]
# # Bar Plots

# %%
sum(tac[pids[0]]['TAC_Reading']>=0.08)

print(sum(sum(tac[pid]['TAC_Reading'] >= 0.08) for pid in pids))
print(sum(sum(tac[pid]['TAC_Reading'] < 0.08) for pid in pids))
# Out:
# 174
# 541

# %%
labels = 'Sober', 'Intoxicated'
sections = [541, 174]
colors = ['teal', 'crimson']

plt.pie(sections, labels=labels, colors=colors,
        startangle=90,
        explode = (0, 0.05),
        autopct = '%1.1f%%')

plt.axis('equal') # Try commenting this out.
plt.title('TAC results')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['Sober', 'Intoxicated']
students = [541,174]
ax.set_title('Frequency of TAC results')
ax.bar(langs,students,color=['teal','crimson'])
plt.show()

# %% [markdown]
# # Bar plot all

# %%
print('BK7610')
print(sum(tac['BK7610']['TAC_Reading'] >= 0.08))
print(sum(tac['BK7610']['TAC_Reading'] < 0.08))
#print(sum(tac[pid]['TAC_Reading'] < 0.08) for pid in pids[0])

print('BU4707')
print(sum(tac['BU4707']['TAC_Reading'] >= 0.08))
print(sum(tac['BU4707']['TAC_Reading'] < 0.08))

print('CC6740')
print(sum(tac['CC6740']['TAC_Reading'] >= 0.08))
print(sum(tac['CC6740']['TAC_Reading'] < 0.08))

print('DC6359')
print(sum(tac['DC6359']['TAC_Reading'] >= 0.08))
print(sum(tac['DC6359']['TAC_Reading'] < 0.08))

print('DK3500')
print(sum(tac['DK3500']['TAC_Reading'] >= 0.08))
print(sum(tac['DK3500']['TAC_Reading'] < 0.08))

print('HV0618')
print(sum(tac['HV0618']['TAC_Reading'] >= 0.08))
print(sum(tac['HV0618']['TAC_Reading'] < 0.08))

print('JB3156')
print(sum(tac['JB3156']['TAC_Reading'] >= 0.08))
print(sum(tac['JB3156']['TAC_Reading'] < 0.08))

print('JR8022')
print(sum(tac['JR8022']['TAC_Reading'] >= 0.08))
print(sum(tac['JR8022']['TAC_Reading'] < 0.08))

print('MC7070')
print(sum(tac['MC7070']['TAC_Reading'] >= 0.08))
print(sum(tac['MC7070']['TAC_Reading'] < 0.08))

print('MJ8002')
print(sum(tac['MJ8002']['TAC_Reading'] >= 0.08))
print(sum(tac['MJ8002']['TAC_Reading'] < 0.08))

print('PC6771')
print(sum(tac['PC6771']['TAC_Reading'] >= 0.08))
print(sum(tac['PC6771']['TAC_Reading'] < 0.08))

print('SA0297')
print(sum(tac['SA0297']['TAC_Reading'] >= 0.08))
print(sum(tac['SA0297']['TAC_Reading'] < 0.08))

print('SF3079')
print(sum(tac['SF3079']['TAC_Reading'] >= 0.08))
print(sum(tac['SF3079']['TAC_Reading'] < 0.08))
# Out:
# BK7610
# 13
# 44
# BU4707
# 13
# 44
# CC6740
# 17
# 39
# DC6359
# 14
# 41
# DK3500
# 5
# 46
# HV0618
# 9
# 45
# JB3156
# 4
# 51
# JR8022
# 19
# 28
# MC7070
# 23
# 33
# MJ8002
# 16
# 43
# PC6771
# 4
# 52
# SA0297
# 11
# 47
# SF3079
# 26
# 28

# %%
N = 5
menMeans = (77,77,70,74,90,83,92,59,59,75,93,81,51)
womenMeans = (23,23,30,26,10,17,8,41,41,25,7,19,49)
ind = np.arange(N) # the x locations for the groups
ind = ['BK7610', 'BU4707', 'CC6740', 'DC6359', 'DK3500', 'HV0618', 'JB3156', 'JR8022', 'MC7070', 'MJ8002','PC6771', 'SA0297', 'SF3079']
width = 0.35
fig = plt.figure()
ax = fig.add_axes([0,0,1.7,1])
ax.bar(ind, menMeans, width, color='teal')
ax.bar(ind, womenMeans, width,bottom=menMeans, color='crimson')
ax.set_ylabel('TAC results (%)')
ax.set_title('TAC Results for specific user')
ax.set_xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
ax.set_yticks(np.arange(0, 101, 10))
ax.legend(labels=['Sober', 'Intoxicated'])
plt.show()

data = [[44,44,39,41,46,45,51,28,33,43,52,47,28],
[13,13,17,14,5,9,4,19,23,16,4,11,26]]
X2= ['BK7610', 'BU4707', 'CC6740', 'DC6359', 'DK3500', 'HV0618', 'JB3156', 'JR8022', 'MC7070', 'MJ8002','PC6771', 'SA0297', 'SF3079']
X = np.arange(13)
fig = plt.figure()
ax = fig.add_axes([0,0,1.7,1])
ax.set_ylabel('Percentage of TAC tests')
ax.set_title('TAC Results for specific user')
ax.bar(X + 0.00, data[0], color = 'teal', width = 0.17)
ax.bar(X + 0.25, data[1], color = 'crimson', width = 0.17)
ax.legend(labels=['Sober', 'Intoxicated'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   del sys.path[0]
